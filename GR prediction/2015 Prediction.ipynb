# %%
import numpy as np
import matplotlib.pyplot as plt
import pprint,sys
from icecream import ic
from scipy.integrate import simpson
import pandas as pd

# %%
def normalize(beta, sigma0, nyear=1024, n=5000):

    # Frequency grid (avoid ν=0)
    nu_start = 0.5 / nyear
    nu_end   = 0.5 * (nyear - 1) / nyear 
    nu = np.linspace(nu_start, nu_end, n)

    # Raw (unnormalized) power
    P = nu**(-beta)
    s = simpson(P, x=nu)

    a = (sigma0**2) / s
    return a, nu

def xir(a, drought_length, tau, beta, nu):
 
    tau = np.atleast_1d(tau)                
    L = drought_length
    arg = np.pi * nu * L                    
    window_sq = np.sinc(arg / np.pi)**2     

    # Spectrum
    Pnu = a * nu**(-beta) * window_sq       

    # Cosine term cos(2πντ) for all τ: outer product
    cos_term = np.cos(2.0 * np.pi * np.outer(tau, nu))   

    # Integrand and integrate over ν (axis=1)
    integrand = cos_term * Pnu
    xi_tau = simpson(integrand, x=nu, axis=1)
    return xi_tau if xi_tau.size > 1 else xi_tau.item()

# -------------------------------
# Parameters
# -------------------------------

sigma0 = 4.5     
nyear  = 1000
n      = 5000
tau = np.arange(1, 101, 1)   
drought_length = 15 
dfs = {}

# Normalize spectrum
beta_values = [0, 0.5, 1]   

for b in beta_values:
    # Normalize for this beta
    a, nu = normalize(b, sigma0, nyear=nyear, n=n)

    # Compute ξ(τ)
    xi = xir(a, drought_length, tau, b, nu)

    # Optional: print rounded values
    for t, val in zip(tau, np.round(xi, 2)):
        print(f"beta={b}, tau={t:>3d}, xi={val: .2f}")

    # Save to Excel for this beta
    df = pd.DataFrame({"tau": tau, "xi": np.round(xi, 2)})
    df.to_excel(f"correlation_{b}.xlsx", index=False)

    
# quick plot
#try:
    #plt.figure()
    #plt.plot(tau, xi)
    #plt.xlabel(r'$\tau$ (years)')
    #plt.ylabel(r'$\xi(\tau)$')
    #plt.title('Correlation function with drought window')
    #plt.tight_layout()
    #plt.show()
#except Exception as e:
    #pass
# Out:
# beta=0, tau=  1, xi= 1.24
# beta=0, tau=  2, xi= 1.15
# beta=0, tau=  3, xi= 1.06
# beta=0, tau=  4, xi= 0.97
# beta=0, tau=  5, xi= 0.88
# beta=0, tau=  6, xi= 0.79
# beta=0, tau=  7, xi= 0.70
# beta=0, tau=  8, xi= 0.61
# beta=0, tau=  9, xi= 0.52
# beta=0, tau= 10, xi= 0.43
# beta=0, tau= 11, xi= 0.34
# beta=0, tau= 12, xi= 0.25
# beta=0, tau= 13, xi= 0.16
# beta=0, tau= 14, xi= 0.07
# beta=0, tau= 15, xi=-0.01
# beta=0, tau= 16, xi=-0.02
# beta=0, tau= 17, xi=-0.02
# beta=0, tau= 18, xi=-0.02
# beta=0, tau= 19, xi=-0.02
# beta=0, tau= 20, xi=-0.02
# beta=0, tau= 21, xi=-0.02
# beta=0, tau= 22, xi=-0.02
# beta=0, tau= 23, xi=-0.02
# beta=0, tau= 24, xi=-0.02
# beta=0, tau= 25, xi=-0.02
# beta=0, tau= 26, xi=-0.02
# beta=0, tau= 27, xi=-0.02
# beta=0, tau= 28, xi=-0.02
# beta=0, tau= 29, xi=-0.02
# beta=0, tau= 30, xi=-0.02
# beta=0, tau= 31, xi=-0.02
# beta=0, tau= 32, xi=-0.02
# beta=0, tau= 33, xi=-0.02
# beta=0, tau= 34, xi=-0.02
# beta=0, tau= 35, xi=-0.02
# beta=0, tau= 36, xi=-0.02
# beta=0, tau= 37, xi=-0.02
# beta=0, tau= 38, xi=-0.02
# beta=0, tau= 39, xi=-0.02
# beta=0, tau= 40, xi=-0.02
# beta=0, tau= 41, xi=-0.02
# beta=0, tau= 42, xi=-0.02
# beta=0, tau= 43, xi=-0.02
# beta=0, tau= 44, xi=-0.02
# beta=0, tau= 45, xi=-0.02
# beta=0, tau= 46, xi=-0.02
# beta=0, tau= 47, xi=-0.02
# beta=0, tau= 48, xi=-0.02
# beta=0, tau= 49, xi=-0.02
# beta=0, tau= 50, xi=-0.02
# beta=0, tau= 51, xi=-0.02
# beta=0, tau= 52, xi=-0.02
# beta=0, tau= 53, xi=-0.02
# beta=0, tau= 54, xi=-0.02
# beta=0, tau= 55, xi=-0.02
# beta=0, tau= 56, xi=-0.02
# beta=0, tau= 57, xi=-0.02
# beta=0, tau= 58, xi=-0.02
# beta=0, tau= 59, xi=-0.02
# beta=0, tau= 60, xi=-0.02
# beta=0, tau= 61, xi=-0.02
# beta=0, tau= 62, xi=-0.02
# beta=0, tau= 63, xi=-0.02
# beta=0, tau= 64, xi=-0.02
# beta=0, tau= 65, xi=-0.02
# beta=0, tau= 66, xi=-0.02
# beta=0, tau= 67, xi=-0.02
# beta=0, tau= 68, xi=-0.02
# beta=0, tau= 69, xi=-0.02
# beta=0, tau= 70, xi=-0.02
# beta=0, tau= 71, xi=-0.02
# beta=0, tau= 72, xi=-0.02
# beta=0, tau= 73, xi=-0.02
# beta=0, tau= 74, xi=-0.02
# beta=0, tau= 75, xi=-0.02
# beta=0, tau= 76, xi=-0.02
# beta=0, tau= 77, xi=-0.02
# beta=0, tau= 78, xi=-0.02
# beta=0, tau= 79, xi=-0.02
# beta=0, tau= 80, xi=-0.02
# beta=0, tau= 81, xi=-0.02
# beta=0, tau= 82, xi=-0.02
# beta=0, tau= 83, xi=-0.02
# beta=0, tau= 84, xi=-0.02
# beta=0, tau= 85, xi=-0.02
# beta=0, tau= 86, xi=-0.02
# beta=0, tau= 87, xi=-0.02
# beta=0, tau= 88, xi=-0.02
# beta=0, tau= 89, xi=-0.02
# beta=0, tau= 90, xi=-0.02
# beta=0, tau= 91, xi=-0.02
# beta=0, tau= 92, xi=-0.02
# beta=0, tau= 93, xi=-0.02
# beta=0, tau= 94, xi=-0.02
# beta=0, tau= 95, xi=-0.02
# beta=0, tau= 96, xi=-0.02
# beta=0, tau= 97, xi=-0.02
# beta=0, tau= 98, xi=-0.02
# beta=0, tau= 99, xi=-0.02
# beta=0, tau=100, xi=-0.02
# beta=0.5, tau=  1, xi= 4.35
# beta=0.5, tau=  2, xi= 4.22
# beta=0.5, tau=  3, xi= 4.05
# beta=0.5, tau=  4, xi= 3.87
# beta=0.5, tau=  5, xi= 3.67
# beta=0.5, tau=  6, xi= 3.45
# beta=0.5, tau=  7, xi= 3.23
# beta=0.5, tau=  8, xi= 3.00
# beta=0.5, tau=  9, xi= 2.77
# beta=0.5, tau= 10, xi= 2.54
# beta=0.5, tau= 11, xi= 2.30
# beta=0.5, tau= 12, xi= 2.07
# beta=0.5, tau= 13, xi= 1.85
# beta=0.5, tau= 14, xi= 1.64
# beta=0.5, tau= 15, xi= 1.45
# beta=0.5, tau= 16, xi= 1.34
# beta=0.5, tau= 17, xi= 1.25
# beta=0.5, tau= 18, xi= 1.18
# beta=0.5, tau= 19, xi= 1.12
# beta=0.5, tau= 20, xi= 1.06
# beta=0.5, tau= 21, xi= 1.01
# beta=0.5, tau= 22, xi= 0.97
# beta=0.5, tau= 23, xi= 0.93
# beta=0.5, tau= 24, xi= 0.89
# beta=0.5, tau= 25, xi= 0.86
# beta=0.5, tau= 26, xi= 0.82
# beta=0.5, tau= 27, xi= 0.79
# beta=0.5, tau= 28, xi= 0.76
# beta=0.5, tau= 29, xi= 0.74
# beta=0.5, tau= 30, xi= 0.71
# beta=0.5, tau= 31, xi= 0.69
# beta=0.5, tau= 32, xi= 0.67
# beta=0.5, tau= 33, xi= 0.64
# beta=0.5, tau= 34, xi= 0.62
# beta=0.5, tau= 35, xi= 0.60
# beta=0.5, tau= 36, xi= 0.59
# beta=0.5, tau= 37, xi= 0.57
# beta=0.5, tau= 38, xi= 0.55
# beta=0.5, tau= 39, xi= 0.54
# beta=0.5, tau= 40, xi= 0.52
# beta=0.5, tau= 41, xi= 0.50
# beta=0.5, tau= 42, xi= 0.49
# beta=0.5, tau= 43, xi= 0.48
# beta=0.5, tau= 44, xi= 0.46
# beta=0.5, tau= 45, xi= 0.45
# beta=0.5, tau= 46, xi= 0.44
# beta=0.5, tau= 47, xi= 0.43
# beta=0.5, tau= 48, xi= 0.41
# beta=0.5, tau= 49, xi= 0.40
# beta=0.5, tau= 50, xi= 0.39
# beta=0.5, tau= 51, xi= 0.38
# beta=0.5, tau= 52, xi= 0.37
# beta=0.5, tau= 53, xi= 0.36
# beta=0.5, tau= 54, xi= 0.35
# beta=0.5, tau= 55, xi= 0.34
# beta=0.5, tau= 56, xi= 0.33
# beta=0.5, tau= 57, xi= 0.32
# beta=0.5, tau= 58, xi= 0.32
# beta=0.5, tau= 59, xi= 0.31
# beta=0.5, tau= 60, xi= 0.30
# beta=0.5, tau= 61, xi= 0.29
# beta=0.5, tau= 62, xi= 0.28
# beta=0.5, tau= 63, xi= 0.28
# beta=0.5, tau= 64, xi= 0.27
# beta=0.5, tau= 65, xi= 0.26
# beta=0.5, tau= 66, xi= 0.25
# beta=0.5, tau= 67, xi= 0.25
# beta=0.5, tau= 68, xi= 0.24
# beta=0.5, tau= 69, xi= 0.23
# beta=0.5, tau= 70, xi= 0.23
# beta=0.5, tau= 71, xi= 0.22
# beta=0.5, tau= 72, xi= 0.22
# beta=0.5, tau= 73, xi= 0.21
# beta=0.5, tau= 74, xi= 0.20
# beta=0.5, tau= 75, xi= 0.20
# beta=0.5, tau= 76, xi= 0.19
# beta=0.5, tau= 77, xi= 0.19
# beta=0.5, tau= 78, xi= 0.18
# beta=0.5, tau= 79, xi= 0.18
# beta=0.5, tau= 80, xi= 0.17
# beta=0.5, tau= 81, xi= 0.17
# beta=0.5, tau= 82, xi= 0.16
# beta=0.5, tau= 83, xi= 0.16
# beta=0.5, tau= 84, xi= 0.15
# beta=0.5, tau= 85, xi= 0.15
# beta=0.5, tau= 86, xi= 0.14
# beta=0.5, tau= 87, xi= 0.14
# beta=0.5, tau= 88, xi= 0.13
# beta=0.5, tau= 89, xi= 0.13
# beta=0.5, tau= 90, xi= 0.12
# beta=0.5, tau= 91, xi= 0.12
# beta=0.5, tau= 92, xi= 0.12
# beta=0.5, tau= 93, xi= 0.11
# beta=0.5, tau= 94, xi= 0.11
# beta=0.5, tau= 95, xi= 0.10
# beta=0.5, tau= 96, xi= 0.10
# beta=0.5, tau= 97, xi= 0.10
# beta=0.5, tau= 98, xi= 0.09
# beta=0.5, tau= 99, xi= 0.09
# beta=0.5, tau=100, xi= 0.09
# beta=1, tau=  1, xi= 11.61
# beta=1, tau=  2, xi= 11.48
# beta=1, tau=  3, xi= 11.30
# beta=1, tau=  4, xi= 11.08
# beta=1, tau=  5, xi= 10.82
# beta=1, tau=  6, xi= 10.54
# beta=1, tau=  7, xi= 10.23
# beta=1, tau=  8, xi= 9.91
# beta=1, tau=  9, xi= 9.58
# beta=1, tau= 10, xi= 9.23
# beta=1, tau= 11, xi= 8.89
# beta=1, tau= 12, xi= 8.55
# beta=1, tau= 13, xi= 8.21
# beta=1, tau= 14, xi= 7.89
# beta=1, tau= 15, xi= 7.60
# beta=1, tau= 16, xi= 7.35
# beta=1, tau= 17, xi= 7.13
# beta=1, tau= 18, xi= 6.94
# beta=1, tau= 19, xi= 6.75
# beta=1, tau= 20, xi= 6.58
# beta=1, tau= 21, xi= 6.42
# beta=1, tau= 22, xi= 6.27
# beta=1, tau= 23, xi= 6.13
# beta=1, tau= 24, xi= 6.00
# beta=1, tau= 25, xi= 5.87
# beta=1, tau= 26, xi= 5.75
# beta=1, tau= 27, xi= 5.63
# beta=1, tau= 28, xi= 5.52
# beta=1, tau= 29, xi= 5.41
# beta=1, tau= 30, xi= 5.30
# beta=1, tau= 31, xi= 5.20
# beta=1, tau= 32, xi= 5.11
# beta=1, tau= 33, xi= 5.01
# beta=1, tau= 34, xi= 4.92
# beta=1, tau= 35, xi= 4.84
# beta=1, tau= 36, xi= 4.75
# beta=1, tau= 37, xi= 4.67
# beta=1, tau= 38, xi= 4.59
# beta=1, tau= 39, xi= 4.51
# beta=1, tau= 40, xi= 4.44
# beta=1, tau= 41, xi= 4.36
# beta=1, tau= 42, xi= 4.29
# beta=1, tau= 43, xi= 4.22
# beta=1, tau= 44, xi= 4.15
# beta=1, tau= 45, xi= 4.09
# beta=1, tau= 46, xi= 4.02
# beta=1, tau= 47, xi= 3.96
# beta=1, tau= 48, xi= 3.90
# beta=1, tau= 49, xi= 3.84
# beta=1, tau= 50, xi= 3.78
# beta=1, tau= 51, xi= 3.72
# beta=1, tau= 52, xi= 3.66
# beta=1, tau= 53, xi= 3.61
# beta=1, tau= 54, xi= 3.55
# beta=1, tau= 55, xi= 3.50
# beta=1, tau= 56, xi= 3.44
# beta=1, tau= 57, xi= 3.39
# beta=1, tau= 58, xi= 3.34
# beta=1, tau= 59, xi= 3.29
# beta=1, tau= 60, xi= 3.24
# beta=1, tau= 61, xi= 3.20
# beta=1, tau= 62, xi= 3.15
# beta=1, tau= 63, xi= 3.10
# beta=1, tau= 64, xi= 3.06
# beta=1, tau= 65, xi= 3.01
# beta=1, tau= 66, xi= 2.97
# beta=1, tau= 67, xi= 2.92
# beta=1, tau= 68, xi= 2.88
# beta=1, tau= 69, xi= 2.84
# beta=1, tau= 70, xi= 2.80
# beta=1, tau= 71, xi= 2.76
# beta=1, tau= 72, xi= 2.72
# beta=1, tau= 73, xi= 2.68
# beta=1, tau= 74, xi= 2.64
# beta=1, tau= 75, xi= 2.60
# beta=1, tau= 76, xi= 2.56
# beta=1, tau= 77, xi= 2.52
# beta=1, tau= 78, xi= 2.49
# beta=1, tau= 79, xi= 2.45
# beta=1, tau= 80, xi= 2.41
# beta=1, tau= 81, xi= 2.38
# beta=1, tau= 82, xi= 2.34
# beta=1, tau= 83, xi= 2.31
# beta=1, tau= 84, xi= 2.27
# beta=1, tau= 85, xi= 2.24
# beta=1, tau= 86, xi= 2.21
# beta=1, tau= 87, xi= 2.17
# beta=1, tau= 88, xi= 2.14
# beta=1, tau= 89, xi= 2.11
# beta=1, tau= 90, xi= 2.08
# beta=1, tau= 91, xi= 2.05
# beta=1, tau= 92, xi= 2.02
# beta=1, tau= 93, xi= 1.99
# beta=1, tau= 94, xi= 1.96
# beta=1, tau= 95, xi= 1.93
# beta=1, tau= 96, xi= 1.90
# beta=1, tau= 97, xi= 1.87
# beta=1, tau= 98, xi= 1.84
# beta=1, tau= 99, xi= 1.81
# beta=1, tau=100, xi= 1.78

# %%
def nearestPD(A):
    """Returns single value decomposition of A Matrix"""
    B = (A + A.T) / 2
    _, s, V = np.linalg.svd(B)

    H = np.dot(V.T, np.dot(np.diag(s), V))

    A2 = (B + H) / 2

    A3 = (A2 + A2.T) / 2

    if isPD(A3):
        return A3
    
    spacing = np.spacing(np.linalg.norm(A))

    I = np.eye(A.shape[0])
    k = 1
    while not isPD(A3):
        mineig = np.min(np.real(np.linalg.eigvals(A3)))
        A3 += I * (-mineig * k**2 + spacing)
        k += 1

    return A3

def isPD(B):
    """Returns true when input is positive-definite, via Cholesky"""
    try:
        _ = np.linalg.cholesky(B)
        return True
    except np.linalg.LinAlgError:
        return False
    
def calcmu(Kstar_star,K,K_star,sigma2_n,flow,nstar):
    L = np.linalg.cholesky(K + sigma2_n*np.eye(len(Year)))
    v = np.linalg.solve(L, K_star)
    mu = mean +np.dot(v.T, np.linalg.solve(L, flow)).reshape((nstar,))

    return mu

def cov(a,b,beta):
    
    df = pd.read_excel(f"correlation_{beta}.xlsx")
    dt = df["tau"].values
    xi = df["xi"].values
    #dt, xi = np.loadtxt(f'kaiserxi15.{beta}.dat', unpack=True)
    ab = np.zeros((len(a), len(b)))
    for i in range(len(a)): 
        for j in range(len(b)):
            tt = abs(a[i]-b[j])
            m = int(tt)
            if (m <= 100):
               ab[i][j] = xi[m]
            else:
               ab[i][j] = 0.02
    return ab

# %%
# --- Load data ---
Yeardat, Flowdat = np.loadtxt('leesnaturalbor15.txt', unpack=True)

# --- Error model and centering ---
FlowErrordat = Flowdat * 0.13
mean = Flowdat.mean()
flowdat = Flowdat - mean
sigma2_n = np.var(FlowErrordat)
#sigma2_n = np.mean(FlowErrordat**2)
sigma2 = np.var(flowdat)

# --- Prediction years (2015–2050 inclusive) ---
YearStar = np.arange(2015, 2051)             # 1-D (needed for cov)
nstar = len(YearStar)

# --- Calibration/observed subset years (1995–2015 inclusive) ---
yb, ye = 1995, 2015
Year = np.arange(yb, ye + 1)                 # 1-D
ny = ye - yb + 1

# Align the last `ny` entries of the full record (1920–2015 => length should be 96)
n_total = len(flowdat)                        # should be 96 for 1920–2015
ist = n_total - ny
idx = np.arange(ist, n_total)                 # last ny indices

flow = flowdat[idx]
Flow = Flowdat[idx]
FlowError = FlowErrordat[idx]

betas = [0, 0.5, 1]                           
mu_by_beta = {}

for beta in betas:
    # Ensure cov() receives 1-D arrays
    Kstar_star = cov(YearStar, YearStar, beta)   # (nstar x nstar)
    K          = cov(Year,     Year,     beta)   # (ny x ny)
    K_star     = cov(Year,     YearStar, beta)   # (ny x nstar)  

    mu_by_beta[beta] = calcmu(Kstar_star, K, K_star, sigma2_n, flow, nstar)

# %%
df = pd.read_excel("Measured.xlsx")
years_me = df.iloc[:, 0].values
flows_me = df.iloc[:, 1].values

# 15-year centered moving average
window = 15
flows_smoothed_end = pd.Series(flows_me).rolling(window=15, closed='right').mean().values
#mask = ~np.isnan(flows_smoothed)
mask = years_me >= 1920
years_filtered = years_me[mask]
flows_filtered = flows_smoothed_end[mask]

# --- Combine into two-column array ---
data_to_save = np.column_stack((years_filtered, flows_filtered))

# --- Save as text file ---
np.savetxt("Smoothed_Streamflow_1920onward.txt", data_to_save,
           fmt="%.0f %.4f", header="Year  Smoothed_Streamflow_MAF", comments='')

print("✅ File saved as 'Smoothed_Streamflow_1920onward.txt'")
# Out:
# ✅ File saved as 'Smoothed_Streamflow_1920onward.txt'

# %%
yearmin = 1920
plt.figure(figsize=(12,6), dpi=100)
plt.xlabel('Year')
plt.ylabel('Streamflow (MAF)')
plt.axis([yearmin, 2050, 10, 20])
#plt.title(r'Effect of varying the $\beta$ parameter ')
plt.plot(years_me, flows_smoothed_end, label="15-yr moving avg_new",color='r')
plt.plot (Yeardat, Flowdat,'grey' )
plt.plot(YearStar, mu_by_beta[0], 'k')
plt.plot(YearStar, mu_by_beta[1], 'k')
plt.plot(YearStar, mu_by_beta[0.5], 'k')
plt.legend()
plt.tick_params('y',labeltop=False, labelright=True, right=True)
plt.text(2040, 14.99, r'$\beta=0$')
plt.text(2040, 13.22, r'$\beta=1$')
plt.text(2040, 14.071, r'$\beta=\frac{1}{2}$')
plt.show()

# %%
mean
# Out:
# 14.842708333333334
